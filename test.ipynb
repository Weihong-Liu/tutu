# %%
import requests

url = "https://wechat.v2.traceint.com/index.php/graphql/"

headers = {
    "Accept-Language": "zh-CN,zh-Hans;q=0.9",
    "Host": "wechat.v2.traceint.com",
    "Sec-Fetch-Site": "same-site",
    "User-Agent": "Mozilla/5.0 (iPhone; CPU iPhone OS 17_5_1 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Mobile/15E148 MicroMessenger/8.0.50(0x1800323d) NetType/WIFI Language/zh_CN",
    "Connection": "keep-alive",
    "Referer": "https://web.traceint.com/",
    "Origin": "https://web.traceint.com",
    "Cookie": "Hm_lpvt_7ecd21a13263a714793f376c18038a87=1726294571; Hm_lvt_7ecd21a13263a714793f376c18038a87=1726280079,1726281092,1726294293; v=5.5; wechatSESS_ID=8d67f9b3d5deef92f54f48a1ef0052fab09330264da17c75; FROM_TYPE=weixin; SERVERID=82967fec9605fac9a28c437e2a3ef1a4|1726294570|1726294291; HMACCOUNT=7B266ABBFCBA5C06; Authorization=eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.eyJ1c2VySWQiOjQyOTI4NTExLCJzY2hJZCI6MjAwMDAsImV4cGlyZUF0IjoxNzI2MzAxNDkyLCJ0YWciOiJjb29raWUifQ.YWisYX8R3gh_xDK3OoqjcPap6HjIj6hrtahUdI4EvQulCz2nzAd6cgPaLyiHk1NV7OitanQWrdfvUxmRy0OYzcP8ApjRz-Tv4z6FHmBwwEHprjpezbEtO29GMpOAx0_dIL0B1SWnAz68sTaJmc3ZAEWyx75oXx6jQfhK7ecbbATZWDALPg89dAa0K9NZS4Z-qbJtjYGHwSdPqE-Ea7WyynOQyIH02u1YIlh8lwY0KXjg0lCSHCcaq1AaU2S2fPNDWgpQZen-rGVLDPImfatIlj6agTXFFTnfD3RTupnATkvkDML_AY2Qq1MRZSzKJUD8hOjm78k8ehMrPc-zQD-D9A",
    "Accept-Encoding": "gzip, deflate, br",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Content-Type": "application/json",
    "App-Version": "2.1.5p1",
    "Accept": "*/*"
}

body = {
    "operationName": "index",
    "query": """query index($pos: String!, $param: [hash]) {
        userAuth {
            oftenseat {
                list {
                    id
                    info
                    lib_id
                    seat_key
                    status
                }
            }
            message {
                new(from: "system") {
                    has
                    from_user
                    title
                    num
                }
                indexMsg {
                    message_id
                    title
                    content
                    isread
                    isused
                    from_user
                    create_time
                }
            }
            reserve {
                reserve {
                    token
                    status
                    user_id
                    user_nick
                    sch_name
                    lib_id
                    lib_name
                    lib_floor
                    seat_key
                    seat_name
                    date
                    exp_date
                    exp_date_str
                    validate_date
                    hold_date
                    diff
                    diff_str
                    mark_source
                    isRecordUser
                    isChooseSeat
                    isRecord
                    mistakeNum
                    openTime
                    threshold
                    daynum
                    closeTime
                    timerange
                    forbidQrValid
                    renewTimeNext
                    forbidRenewTime
                    forbidWechatCancle
                }
                getSToken
            }
            currentUser {
                user_id
                user_nick
                user_mobile
                user_sex
                user_sch_id
                user_sch
                user_last_login
                user_avatar(size: MIDDLE)
                user_adate
                user_student_no
                user_student_name
                area_name
                user_deny {
                    deny_deadline
                }
                sch {
                    sch_id
                    sch_name
                    activityUrl
                    isShowCommon
                    isBusy
                }
            }
        }
        ad(pos: $pos, param: $param) {
            name
            pic
            url
        }
    }""",
    "variables": {
        "pos": "App-首页"
    }
}

response = session.post(url, headers=headers, json=body)

print(response.status_code)
print(response.json())  # Assuming the response is in JSON format
# Out:
# 200
# {'errors': [{'msg': 'access denied!', 'code': 40001}], 'data': {'userAuth': None, 'ad': []}}

# %%
body = {
  "operationName": "reserveSeat",
  "query": "mutation reserveSeat($libId: Int!, $seatKey: String!, $captchaCode: String, $captcha: String!) {\n userAuth {\n reserve {\n reserveSeat(\n libId: $libId\n seatKey: $seatKey\n captchaCode: $captchaCode\n captcha: $captcha\n )\n }\n }\n}",
  "variables": {
    "seatKey": "38,57",
    "libId": 20040,
    "captchaCode": "",
    "captcha": ""
  }
}
response = session.post(url, json=body)
response.text
# Out:
# '<!DOCTYPE html><html lang=zh-CN><head><meta charset=utf-8><meta http-equiv=X-UA-Compatible content="IE=edge"><meta http-equiv=pragma content=no-cache><meta http-equiv=Cache-Control content="no-store, must-revalidate"><meta http-equiv=expires content="Wed, 26 Feb 1997 08:21:57 GMT"><meta http-equiv=expires content=0><title>æ\x88\x91å\x8e»å\x9b¾ä¹¦é¦\x86</title><script src=./static/wanxiao-js-api.js></script><script>window.PointerEvent = void 0;\n\n            var coverSupport = \'CSS\' in window && typeof CSS.supports === \'function\' && (CSS.supports(\'top: env(a)\') || CSS.supports(\'top: constant(a)\'))\n            document.write(\'<meta name="viewport" content="width=device-width, user-scalable=no, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0\' + (coverSupport ? \', viewport-fit=cover\' : \'\') + \'" />\')</script><link rel=stylesheet href=./static/index.a5c69d49.css><script>var _hmt = _hmt || [];\n\t\t(function() {\n\t\t  var hm = document.createElement("script");\n\t\t  hm.src = "https://hm.baidu.com/hm.js?7ecd21a13263a714793f376c18038a87";\n\t\t  var s = document.getElementsByTagName("script")[0]; \n\t\t  s.parentNode.insertBefore(hm, s);\n\t\t})();</script></head><body><noscript><strong>Please enable JavaScript to continue.</strong></noscript><div id=app></div><script src=./static/js/chunk-vendors.bf7763d3.js></script><script src=./static/js/index.27c92fac.js></script></body></html>'

# %%
body = {
  "operationName": "reserveCancle",
  "query": "mutation reserveCancle($sToken: String!) {\n userAuth {\n reserve {\n reserveCancle(sToken: $sToken) {\n timerange\n img\n hours\n mins\n per\n }\n }\n }\n}",
  "variables": {
    "sToken": "616ce4b8ec6b3e272b8d62715b3eb65d66600c59"
  }
}

response = requests.post(url, headers=headers, json=body)

print(response.status_code)
print(response.json())  # Assuming the response is in JSON format
# Out:
# 200
# {'errors': [{'msg': '主动退座成功[1]', 'code': 1}], 'data': {'userAuth': {'reserve': {'reserveCancle': None}}}}

# %%
import http.cookies
import requests
import json
import time
import copy

import constants
import tools

cookie_string = "Authorization=eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.eyJ1c2VySWQiOjQyOTI4NTExLCJzY2hJZCI6MjAwMDAsImV4cGlyZUF0IjoxNzI2Mzg3NTU5LCJ0YWciOiJjb29raWUifQ.I7scC-QGkRoQ9AmBsDPPZSIK7QIC2O7LF1dic16caOQWKASllCqL4hSq42cEYkiiVIP8rlyPebq-QRundXguM1ccRfNISVQD_hBtNQOceYFxgFmApup3tZnAlTBL9cwQgUxeqTw5A0lPWbQahcaC9MbyxIh849rUKdjKNhV2_zS2lqQw8xgmvgNl5PfexG_r6dgcebmhD5eGarbftxjomQlkGtbeDAQch7XF1R8ufyA_Nx3ZJ-SyhFcFqrzwm6WDuM1QO7G6c9s7eQ-up3UZEDYLZ8IEtXOxGGxDCnoAS2_da1mQllCUtXWVpUGABnmKafBsfHo0Ql0YS50-MRICRg; SERVERID=e3fa93b0fb9e2e6d4f53273540d4e924|1726380360|1726380360; SERVERID=e3fa93b0fb9e2e6d4f53273540d4e924|1726380359|1726380359"

session = tools.get_session(cookie_string)

# %%
index_data = tools.get_index_data(session)

print(json.dumps(index_data, ensure_ascii=False, indent=4))  # Assuming the response is in JSON format
# Out:
# Session expired!
# null

# %%
def get_resverve_stoken(index_data):
    """获取预约座位的stoken

    Args:
        index_data (dict): get_index_data 返回的结果

    Returns:
        str: stoken
    """
    return index_data['data']['userAuth']['reserve']['getSToken']

get_resverve_stoken(index_data)
# Out:
# '1b05ca19ca6f569e1c592ea107fbaa82436a9b59'

# %%
def get_often_seat(result, index=0):
    """获取常用座位信息

    Args:
        result (dict): get_index_data 返回的结果
        index (int, optional): 常用座位index，默认第一个. Defaults to 0.

    Returns:
        dict:常用座位信息
        {
            "id": 17620927,
            "info": "A区2楼自习室 143号",
            "lib_id": 20040,
            "seat_key": "38,57",
            "status": 1
        }
    """
    return result["data"]["userAuth"]["oftenseat"]["list"][index]

seat = get_often_seat(index_data, index=1)
seat
# Out:
# {'id': 17620927,
#  'info': 'A区2楼自习室 286号',
#  'lib_id': 20040,
#  'seat_key': '19,27',
#  'status': 0}

# %%
def get_often_seat_status(often_seat):
    """获取常用座位信息状态

    Args:
        often_seat (dict): get_often_seat 返回的结果

    Returns:
        bool: True: 有空位，False: 无空位
    """

    return False if often_seat["status"] else True

get_often_seat_status(seat)
# Out:
# True

# %%
def reserve_seat(session, seat):
    if tools.check_session_status(session) and get_often_seat_status(seat):
        reserve_seat_body = copy.deepcopy(constants.RESERVE_SEAT_BODY)
        reserve_seat_body["variables"]["seatKey"] = seat["seat_key"]
        reserve_seat_body["variables"]["libId"] = seat["lib_id"]

        res = session.post(constants.URL, json=reserve_seat_body)
        try:
            result = res.json()
        except json.decoder.JSONDecodeError as err:
            print("Error: %s" % err)
            return False
        if result.get("errors") and result.get("errors")[0].get("code") != 0:
            print("Failed to reserve seat!")
            return False
        print("Seat reserved successfully.")
        return True

reserve_seat(session, seat)
# Out:
# Session is active.
# Seat reserved successfully.
# True

# %%
def reserve_cancel(session):
    if tools.check_session_status(session):
        index_data = tools.get_index_data(session)
        if not index_data:
            print("Failed to get index data!")
            return False
        
        sToken = get_resverve_stoken(index_data)
        constants.RESERVE_CANCLE_BODY['variables'].update({'sToken': sToken})
        res = session.post(constants.URL, json=constants.RESERVE_CANCLE_BODY)
        try:
            result = res.json()
        except json.decoder.JSONDecodeError as err:
            print("Error: %s" % err)
            return False
        if result.get("errors") and "主动退座成功" in result.get("errors")[0].get("msg"):
            print("Reservation canceled successfully.")
            return True
        else:
            print(result.get("errors")[0].get("msg"))
            return False
    
reserve_cancel(session)
# Out:
# Session is active.
# Session is active.
# {'errors': [{'msg': '您还没有预定座位', 'code': 1}], 'data': {'userAuth': {'reserve': {'reserveCancle': None}}}}
# 您还没有预定座位
# False

# %%
tools.main()
# Out:
# Cookie string:
#
# SERVERID=82967fec9605fac9a28c437e2a3ef1a4|1726385033|1726385033

# %%
import json
import time
import requests
import websocket


cookieStr = 'SERVERID=d3936289adfff6c3874a2579058ac651|1726414090|1726414068; Hm_lpvt_7ecd21a13263a714793f376c18038a87=1726414078; Hm_lvt_7ecd21a13263a714793f376c18038a87=1726294293,1726295723,1726362677,1726411791; v=5.5; wechatSESS_ID=65ea91136846b651feadea15a1c3d07aaa193ebcc28886a1; FROM_TYPE=weixin; HMACCOUNT=64A03F82EF345BAD; Authorization=eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.eyJ1c2VySWQiOjQyOTI4NTExLCJzY2hJZCI6MjAwMDAsImV4cGlyZUF0IjoxNzI2NDE4OTg5LCJ0YWciOiJjb29raWUifQ.OKfKmmEFPZSC4KWZwYQBsT4wpP48i0ibLU9omfKlQ7F7B9Mdy7wJb5LQFf6OzldQKV5jqJMZLD7BkSKS5JZ_fJnnb59qwyqMLx8OJiOc4bkoWYIFwzMj42DEtefys3iC756xxlcywoLjqv_gPGjEEIXT_55w334TDu4GYsSlpcI3a7IZ57CXPidQhj3gygOFvBLlABBqtT_arxq01TDeRjwx-7Pd8nfs4lRii3fmBzZ8B9VmLASfLmwpkBvgLwIsX9pcCBnzR1y3bqsxcG2J6eXpZZCQFeUZ3uhTv-4qklRhurHZEZXm0kGKWTn9lnunl79YK92fKlFJJuODwaO_VQ'


queue_header = {
    "Host": "wechat.v2.traceint.com",
    "Pragma": "no-cache",
    "Accept": "*/*",
    "Sec-WebSocket-Key": "oXNRrZUmWXsDDq1Ay3ceUg==",
    "Sec-Fetch-Site": "same-site",
    "Sec-WebSocket-Version": "13",
    "Sec-WebSocket-Extensions": "permessage-deflate",
    "Cache-Control": "no-cache",
    "Sec-Fetch-Mode": "websocket",
    "Accept-Language": "zh-CN,zh-Hans;q=0.9",
    "Origin": "https://web.traceint.com",
    "User-Agent": "Mozilla/5.0 (iPhone; CPU iPhone OS 17_5_1 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Mobile/15E148 MicroMessenger/8.0.50(0x1800323d) NetType/WIFI Language/zh_CN",
    "Connection": "Upgrade",
    "Accept-Encoding": "gzip, deflate",
    "Upgrade": "websocket",
    "Sec-Fetch-Dest": "websocket",
    'Cookie': cookieStr
}

# 先自己抓包，然后填入请求头中的每一个参数
pre_header = {
    "Accept-Language": "zh-CN,zh-Hans;q=0.9",
    "Host": "wechat.v2.traceint.com",
    "Sec-Fetch-Site": "same-site",
    "User-Agent": "Mozilla/5.0 (iPhone; CPU iPhone OS 17_5_1 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Mobile/15E148 MicroMessenger/8.0.50(0x1800323d) NetType/WIFI Language/zh_CN",
    "Connection": "keep-alive",
    "Referer": "https://web.traceint.com/",
    "Origin": "https://web.traceint.com",
    "Accept-Encoding": "gzip, deflate, br",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Content-Type": "application/json",
    "App-Version": "2.1.5p1",
    "Accept": "*/*",
    'Cookie': cookieStr
}

# 预约data
data = {
    "operationName": "save",
    "query": "mutation save($key: String!, $libid: Int!, $captchaCode: String, $captcha: String) {\n userAuth {\n prereserve {\n save(key: $key, libId: $libid, captcha: $captcha, captchaCode: $captchaCode)\n }\n }\n}",
    "variables": {
        "key": "51,14",
        "libid": 20038,
        "captchaCode": "",
        "captcha": ""
    }
}
# # 抢座data
# data3 = \
#     {"operationName": "reserveSeat",
#      "query": "mutation reserveSeat($libId: Int!, $seatKey: String!, $captchaCode: String, $captcha: String!) {\n userAuth {\n reserve {\n reserveSeat(\n libId: $libId\n seatKey: $seatKey\n captchaCode: $captchaCode\n captcha: $captcha\n )\n }\n }\n}",
#      "variables": {"seatKey": "35,18", "libId": 525, "captchaCode": "", "captcha": ""}}
data2 = {
    "operationName": "prereserve",
    "query": "query prereserve {\n userAuth {\n prereserve {\n prereserve {\n day\n lib_id\n seat_key\n seat_name\n is_used\n user_mobile\n id\n lib_name\n }\n }\n }\n}"
}
data3 = {"operationName": "index",
         "query": "query index {\n userAuth {\n user {\n prereserveAuto: getSchConfig(extra: true, fields: \"prereserve.auto\")\n }\n currentUser {\n sch {\n isShowCommon\n }\n }\n prereserve {\n libs {\n is_open\n lib_floor\n lib_group_id\n lib_id\n lib_name\n num\n seats_total\n }\n }\n oftenseat {\n prereserveList {\n id\n info\n lib_id\n seat_key\n status\n }\n }\n }\n}"}
data4 = {"operationName": "prereserveCheckMsg",
         "query": "query prereserveCheckMsg {\n userAuth {\n prereserve {\n prereserveCheckMsg\n }\n }\n}"}
data_lib_chosen = {
    "operationName": "libLayout",
    "query": "query libLayout($libId: Int!) {\n userAuth {\n prereserve {\n libLayout(libId: $libId) {\n max_x\n max_y\n seats_booking\n seats_total\n seats_used\n seats {\n key\n name\n seat_status\n status\n type\n x\n y\n }\n }\n }\n }\n}",
    "variables": {
        "libId": 490
    }
}

def pass_queue():
    print("================================")
    print("开始排队。。。")
    ws = websocket.WebSocket()
    
    # ws.connect("wss://XXXX/ws?ns=prereserve/queue", header=headers)
    ws.connect('wss://wechat.v2.traceint.com/ws?ns=prereserve/queue', header=queue_header, verify=False)  # 这里的XXXX和Host内容是一致的

    if ws.connected:
        print('test pass queue connect')
        while True:
            ws.send('{"ns":"prereserve/queue","msg":""}')
            a = ws.recv()
            if a.find('u6392') != -1:  # 排队成功返回的第一个字符
                break
            if a.find('u6210') != -1:  # 已经抢座成功的返回
                print("rsp msg:{}".format(json.loads(str(a))["msg"]))
                time.sleep(5)
                break
            print("排队中，rsp:{}".format(a))
            # time.sleep(0.01)
        # 关闭连接
        ws.close()
    # time.sleep(0.01)
    print("排队结束。。。")
    print("================================")


def time_update():
    # struct_openTime = "****-**-** 21:00:00"
    now = time.gmtime()
    return now.tm_year.__str__() + '-' + now.tm_mon.__str__() + '-' + now.tm_mday.__str__() + ' 21:00:00'

# %%
pass_queue()
# Out:
# ================================
# 开始排队。。。
# test pass queue connect
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队结束。。。
# ================================

# %%
url = "https://wechat.v2.traceint.com/index.php/graphql/"

try:
    pass_queue()
    pass_queue()

    print('test pass queue ==> ok!')
    # 重要！如果不是放在常用座位，需要先请求对应的阅览室的所有座位，libLayout！！
    # requests.post(url=url, headers=pre_header, json=data_lib_chosen, verify=False)
    # 抢座的post请求，core code
    res = requests.post(url=url, headers=pre_header, json=data, verify=False)
    print('test request ==> ok!')
    print(res.text)
    text_Res = requests.post(url=url, headers=pre_header, json=data2, verify=False).text
    unicode = str(res.text).encode('utf-8').decode('unicode_escape')
    text_uni = str(text_Res).encode('utf-8').decode('unicode_escape')
    print(text_uni)
    print(unicode)
    if str(res.text).count("true") and text_Res.count('user_mobile'):
        print("******************************")
        print("恭喜你！预定成功！程序即将结束......")
        print("******************************\n")
    else:
        # print('---睡眠0.3s---')
        pass_queue()
        pass_queue()
        time.sleep(0.3)
except Exception as e:
    time.sleep(0.3)
    print(e)
# Out:
# ================================
# 开始排队。。。
# test pass queue connect
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# ...
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# 排队中，rsp:{"ns":"prereserve\/queue","msg":"\u4e0d\u5728\u9884\u7ea6\u65f6\u95f4\u5185,\u8bf7\u5728 22:00-23:59 \u6765\u9884\u7ea6","code":0,"data":0}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 4
#       1 url = "https://wechat.v2.traceint.com/index.php/graphql/"
#       3 try:
# ----> 4     pass_queue()
#       5     pass_queue()
#       7     print('test pass queue ==> ok!')
#
# Cell In[3], line 92, in pass_queue()
#      90 while True:
#      91     ws.send('{"ns":"prereserve/queue","msg":""}')
# ---> 92     a = ws.recv()
#      93     if a.find('u6392') != -1:  # 排队成功返回的第一个字符
#      94         break
#
# File ~/Documents/GitHub/tutu/venv/lib/python3.9/site-packages/websocket/_core.py:388, in WebSocket.recv(self)
#     380 """
#     381 Receive string data(byte array) from the server.
#     382
#    (...)
#     385 data: string (byte array) value.
#     386 """
#     387 with self.readlock:
# --> 388     opcode, data = self.recv_data()
#     389 if opcode == ABNF.OPCODE_TEXT:
#     390     data_received: Union[bytes, str] = data
#
# File ~/Documents/GitHub/tutu/venv/lib/python3.9/site-packages/websocket/_core.py:416, in WebSocket.recv_data(self, control_frame)
#     401 def recv_data(self, control_frame: bool = False) -> tuple:
#     402     """
#     403     Receive data with operation code.
#     404
#    (...)
#     414         tuple of operation code and string(byte array) value.
#     415     """
# --> 416     opcode, frame = self.recv_data_frame(control_frame)
#     417     return opcode, frame.data
#
# File ~/Documents/GitHub/tutu/venv/lib/python3.9/site-packages/websocket/_core.py:437, in WebSocket.recv_data_frame(self, control_frame)
#     420 """
#     421 Receive data with operation code.
#     422
#    (...)
#     434     tuple of operation code and string(byte array) value.
#     435 """
#     436 while True:
# --> 437     frame = self.recv_frame()
#     438     if isEnabledForTrace():
#     439         trace(f"++Rcv raw: {repr(frame.format())}")
#
# File ~/Documents/GitHub/tutu/venv/lib/python3.9/site-packages/websocket/_core.py:478, in WebSocket.recv_frame(self)
#     470 def recv_frame(self):
#     471     """
#     472     Receive data as frame from server.
#     473
#    (...)
#     476     self.frame_buffer.recv_frame(): ABNF frame object
#     477     """
# --> 478     return self.frame_buffer.recv_frame()
#
# File ~/Documents/GitHub/tutu/venv/lib/python3.9/site-packages/websocket/_abnf.py:363, in frame_buffer.recv_frame(self)
#     360 with self.lock:
#     361     # Header
#     362     if self.has_received_header():
# --> 363         self.recv_header()
#     364     (fin, rsv1, rsv2, rsv3, opcode, has_mask, _) = self.header
#     366     # Frame length
#
# File ~/Documents/GitHub/tutu/venv/lib/python3.9/site-packages/websocket/_abnf.py:319, in frame_buffer.recv_header(self)
#     318 def recv_header(self) -> None:
# --> 319     header = self.recv_strict(2)
#     320     b1 = header[0]
#     321     fin = b1 >> 7 & 1
#
# File ~/Documents/GitHub/tutu/venv/lib/python3.9/site-packages/websocket/_abnf.py:398, in frame_buffer.recv_strict(self, bufsize)
#     390 shortage = bufsize - sum(map(len, self.recv_buffer))
#     391 while shortage > 0:
#     392     # Limit buffer size that we pass to socket.recv() to avoid
#     393     # fragmenting the heap -- the number of bytes recv() actually
#    (...)
#     396     # buffers allocated and then shrunk, which results in
#     397     # fragmentation.
# --> 398     bytes_ = self.recv(min(16384, shortage))
#     399     self.recv_buffer.append(bytes_)
#     400     shortage -= len(bytes_)
#
# File ~/Documents/GitHub/tutu/venv/lib/python3.9/site-packages/websocket/_core.py:563, in WebSocket._recv(self, bufsize)
#     561 def _recv(self, bufsize):
#     562     try:
# --> 563         return recv(self.sock, bufsize)
#     564     except WebSocketConnectionClosedException:
#     565         if self.sock:
#
# File ~/Documents/GitHub/tutu/venv/lib/python3.9/site-packages/websocket/_socket.py:118, in recv(sock, bufsize)
#     116         bytes_ = sock.recv(bufsize)
#     117     else:
# --> 118         bytes_ = _recv()
#     119 except TimeoutError:
#     120     raise WebSocketTimeoutException("Connection timed out")
#
# File ~/Documents/GitHub/tutu/venv/lib/python3.9/site-packages/websocket/_socket.py:97, in recv.<locals>._recv()
#      95 def _recv():
#      96     try:
# ---> 97         return sock.recv(bufsize)
#      98     except SSLWantReadError:
#      99         pass
#
# File ~/miniconda3/lib/python3.9/ssl.py:1260, in SSLSocket.recv(self, buflen, flags)
#    1256     if flags != 0:
#    1257         raise ValueError(
#    1258             "non-zero flags not allowed in calls to recv() on %s" %
#    1259             self.__class__)
# -> 1260     return self.read(buflen)
#    1261 else:
#    1262     return super().recv(buflen, flags)
#
# File ~/miniconda3/lib/python3.9/ssl.py:1135, in SSLSocket.read(self, len, buffer)
#    1133         return self._sslobj.read(len, buffer)
#    1134     else:
# -> 1135         return self._sslobj.read(len)
#    1136 except SSLError as x:
#    1137     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
requests.post(url=url, headers=pre_header, json=data2, verify=False).text
# Out:
# /Users/puppet/Documents/GitHub/tutu/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# '{"data":{"userAuth":{"prereserve":{"prereserve":null}}}}'

# %%
pass_queue()
# Out:
# ================================
# 开始排队。。。
# test pass queue connect
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队中，rsp:{"ns":"prereserve\/queue","code":0,"data":1}
# 排队结束。。。
# ================================

# %%
res = requests.post(url=url, headers=pre_header, json=data, verify=False)
res.text
# Out:
# /Users/puppet/Documents/GitHub/tutu/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# '{"data":{"userAuth":{"prereserve":{"save":true}}}}'
